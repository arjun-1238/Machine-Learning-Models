# %% [markdown]
# <a href="https://colab.research.google.com/github/arjun-1238/Machine-Learning-Models/blob/main/DecisionTree_titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/titanic.csv")
df.columns
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1181/2561728758.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 df=pd.read_csv("/content/titanic.csv")
#       3 df.columns
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df=df[["Survived","Sex","Age","Cabin","Embarked"]]

# %%
df["Age"]=df["Age"].fillna(df["Age"].mean())
print(df.head(20))

# %%
df.drop("Cabin",axis=1,inplace=True)
print(df.head(20))

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["Sex"]=le.fit_transform(df["Sex"])

df=pd.get_dummies(df,columns=["Embarked"])
print(df.head(20))

# %%
df["Age"]=df["Age"].astype(int)
print(df.head(20))

# %%
x=df[["Age","Sex","Embarked_C","Embarked_Q","Embarked_S"]]
y=df["Survived"]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score , classification_report,confusion_matrix

# %%
model=DecisionTreeClassifier(criterion="gini", max_depth=3)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42,stratify=y)

# %%
model.fit(x_train,y_train)
predict=model.predict(x_test)
accuracy=accuracy_score(y_test,predict)
print(accuracy)
print(classification_report(y_test,predict))
confusion_matrix(y_test,predict)

# %%
df.shape

# %% [markdown]
# BELOW IS THE RIGHT DATASET OF TITANIC

# %%
import pandas as pd


url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

df.to_csv("/content/titanic.csv", index=False)

# %%
df.shape
# Out:
# (891, 12)

# %%
df=df[["Survived","Sex","Age","Cabin","Embarked"]]
df.isnull().sum()
# Out:
# Survived      0
# Sex           0
# Age         177
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df.drop("Cabin",axis=1,inplace=True)
df["Age"]=df["Age"].fillna(df["Age"].mean())

# %%
df.head()

# %%
le=LabelEncoder()
df["Sex"]=le.fit_transform(df["Sex"])
df=pd.get_dummies(df,columns=["Embarked"])

# %%
x=df.drop("Survived",axis=1)
y=df["Survived"]

# %%
model=DecisionTreeClassifier(criterion="gini",max_depth=3)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42,stratify=y)
df.head()

# %%
model.fit(x_train,y_train)
predict = model.predict(x_test)

# %%
print(accuracy_score(y_test,predict))
print(classification_report(y_test,predict))
confusion_matrix(y_test,predict)

# %%
df.shape
